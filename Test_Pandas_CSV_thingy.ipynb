# %%
import pandas as pd
import numpy as np

# %% [markdown]
# After imports we test the items

# %%
seed = 7
np.random.seed(seed)

dataframe = pd.read_csv("BBCN.csv")

num_rows = dataframe.shape[0]
num_columns = dataframe.shape[1]

dataframe
# Out:
#      MaritalStatus  Gender  YearlyIncome  TotalChildren  NumberChildrenAtHome  \
# 0                5       1           9.0              2                     0
# 1                5       1           6.0              3                     3
# 2                5       1           6.0              3                     3
# 3                5       2           7.0              0                     0
# 4                5       2           8.0              5                     5
# 5                5       1           7.0              0                     0
# 6                5       2           7.0              0                     0
# 7                5       1           6.0              3                     3
# 8                5       2           6.0              4                     4
# 9                5       1           7.0              0                     0
# 10               5       2           7.0              0                     0
# ...
